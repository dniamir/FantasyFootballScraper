# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import copy

pd.set_option('display.max_columns', 500)

# %matplotlib inline

# %%
from FFBAnalysis import LeagueSettings, PlayerProfile, FFBAnalyzer

# %%
FFBA = FFBAnalyzer(filepath='./Data')

# %%
fig = FFBA.PlotPlayerPoints(['Andrew Luck', 
                             'Drew Brees', 
                             'Tom Brady', 
                             'Patrick Mahomes', 
                             'Matt Ryan',
                             'Matthew Stafford',
                             'Aaron Rodgers',
                             'Russell Wilson'])
plt.savefig('QBs')
# Out:
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4042: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   method=method)

# %%
fig = FFBA.PlotPlayerPoints(['Ezekiel Elliott',
                             'David Johnson',
                             "Le'Veon Bell",
                             'Todd Gurley', 
                             'Melvin Gordon',
                             'Joe Mixon'])
plt.savefig('RBs')

# %%
fig = FFBA.PlotPlayerPoints(['DeAndre Hopkins',
                             'Julio Jones',
                             'Michael Thomas',
                             'Mike Evans', 
                             'Odell Beckham',
                             'Antonio Brown'])
plt.savefig('WRs')
